# %% [markdown]
# Title: **Assignment 1: Study of Deep learning Packages: Tensorflow, Keras, Theano and PyTorch.
# Document the distinct features and functionality of the packages.**<br>

# %%
# Install the numpy package (use !pip or %pip in notebooks)
pip install numpy
# Out:
# ...
#   Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl (12.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import the numpy library and call it 'np'
import numpy as np

# %% [markdown]
# **1. Tensorflow**

# %%
# Install the TensorFlow library
# !pip install tensorflow
# Out:
# ...
#   Using cached protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# ...
#   Using cached h5py-3.15.1-cp313-cp313-win_amd64.whl.metadata (3.1 kB)
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached pillow-12.0.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#    ---------------------------------------- 3.1/332.0 MB 20.9 MB/s eta 0:00:16
#     --------------------------------------- 7.9/332.0 MB 21.6 MB/s eta 0:00:15
#    - -------------------------------------- 15.7/332.0 MB 27.5 MB/s eta 0:00:12
#    -- ------------------------------------- 24.1/332.0 MB 31.3 MB/s eta 0:00:10
#    --- ------------------------------------ 32.8/332.0 MB 33.3 MB/s eta 0:00:09
# ...

# %% [markdown]
# **2. Keras**

# %%
# Get the MNIST digits dataset using Keras
from keras import datasets
# Download the data and split it into training and test parts
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()
# train_images/test_images are pictures (as NumPy arrays),
# train_labels/test_labels are the correct digit numbers (0–9)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Show the shape of the training images: (number_of_images, height, width)
train_images.shape
# Out:
# (60000, 28, 28)

# %%
# Show the shape of the test images: (number_of_images, height, width)
test_images.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# **3. Theano**

# %%
# Install the Theano library
# !pip install Theano
# Out:
# ...
#      ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#      -------------- ------------------------- 1.0/2.8 MB 8.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.8/2.8 MB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [22 lines of output]
#   C:\Windows\Temp\pip-install-kp7qhq3r\theano_1190282075c44bb6a54966187b6963b6\versioneer.py:564: SyntaxWarning: invalid escape sequence '\s'
#     mo = re.search(r'=\s*"(.*)"', line)
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#       exec(compile('''
#       ~~~~^^^^^^^^^^^^
#       # This is <pip-setuptools-caller> -- a caller that pip uses to run setup.py
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       ...<31 lines>...
# ...

# %% [markdown]
# **4. PyTorch**

# %%
# Install PyTorch and vision/audio helper packages (GPU build if supported)
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu115
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu115
# ...
#   Using cached torch-2.9.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# ...
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# ...
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ------------------- -------------------- 262.1/536.2 kB ? eta -:--:--
#      -------------------------------------- 536.2/536.2 kB 1.7 MB/s eta 0:00:00
# ...
# Using cached torch-2.9.0-cp313-cp313-win_amd64.whl (109.3 MB)
# ...
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    --------- ------------------------------ 1.0/4.3 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.3 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 12.4 MB/s eta 0:00:00
# ...

# %%
# Import PyTorch core and its neural-network helpers
import torch
import torch.nn as nn

# %%
# Print the installed PyTorch version
print(torch.__version__)
# Out:
# 2.1.0+cpu

# %%
# Check if a CUDA-capable GPU is available for PyTorch (returns True or False)
torch.cuda.is_available()
# Out:
# False
